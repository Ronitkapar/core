# %%
import pandas as pd

# %%
data=[1,2,3,4,5]
s=pd.Series(data)
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data={'a':1,'b':2,'c':3}
series_dict=pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data=[10,20,30,40,50]
index=['a','b','c','d','e']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
data={
    'name':['Rohan','ramesh','ramu'],
    'Age':[45,55,95],
    'city':['Banglore','shimla','kathmandu']
}

df=pd.DataFrame(data)
print(df)
# Out:
#      name  Age       city
# 0   Rohan   45   Banglore
# 1  ramesh   55     shimla
# 2    ramu   95  kathmandu

# %%
#prints as nested list/Matrix
import numpy as np
print(np.array(df))
# Out:
# [['Rohan' 45 'Banglore']
#  ['ramesh' 55 'shimla']
#  ['ramu' 95 'kathmandu']]

# %%
df=pd.read_csv('sales1000.csv')

# %%
df.head(5)
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
df.tail(10)
# Out:
#                            Region               Country   Item Type  \
# 990            Sub-Saharan Africa                  Mali   Beverages
# 991            Sub-Saharan Africa               Liberia      Cereal
# 992                        Europe           Switzerland   Beverages
# 993         Australia and Oceania                Samoa    Baby Food
# 994                          Asia                 Nepal        Meat
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID  Ship Date  \
# 990        Online              L   3/17/2012  410452497  3/26/2012
# 991       Offline              H  12/17/2015  642683303  1/20/2016
# ...

# %%
pd.isnull(df)
# Out:
#      Region  Country  Item Type  Sales Channel  Order Priority  Order Date  \
# 0     False    False      False          False           False       False
# 1     False    False      False          False           False       False
# 2     False    False      False          False           False       False
# 3     False    False      False          False           False       False
# 4     False    False      False          False           False       False
# ..      ...      ...        ...            ...             ...         ...
# 995   False    False      False          False           False       False
# 996   False    False      False          False           False       False
# 997   False    False      False          False           False       False
# 998   False    False      False          False           False       False
# 999   False    False      False          False           False       False
#
# ...

# %%
df['Region']
# Out:
# 0      Middle East and North Africa
# 1                     North America
# 2      Middle East and North Africa
# 3                              Asia
# 4                Sub-Saharan Africa
#                    ...
# 995    Middle East and North Africa
# 996                          Europe
# 997    Middle East and North Africa
# 998                          Europe
# 999                          Europe
# Name: Region, Length: 1000, dtype: object

# %%
df.drop('Region',axis=1)
# Out:
#                   Country   Item Type Sales Channel Order Priority  \
# 0                   Libya   Cosmetics       Offline              M
# 1                  Canada  Vegetables        Online              M
# 2                   Libya   Baby Food       Offline              C
# 3                   Japan      Cereal       Offline              C
# 4                    Chad      Fruits       Offline              H
# ..                    ...         ...           ...            ...
# 995            Azerbaijan      Snacks       Offline              C
# 996               Georgia   Baby Food       Offline              H
# 997  United Arab Emirates  Vegetables        Online              C
# 998               Finland   Household       Offline              L
# 999              Portugal      Cereal       Offline              C
#
#      Order Date   Order ID   Ship Date  Units Sold  Unit Price  Unit Cost  \
# 0    10/18/2014  686800706  10/31/2014        8446      437.20     263.33
# ...

# %%
df
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
df.drop('Region',axis=1,inplace=True)

# %%
df
# Out:
#                   Country   Item Type Sales Channel Order Priority  \
# 0                   Libya   Cosmetics       Offline              M
# 1                  Canada  Vegetables        Online              M
# 2                   Libya   Baby Food       Offline              C
# 3                   Japan      Cereal       Offline              C
# 4                    Chad      Fruits       Offline              H
# ..                    ...         ...           ...            ...
# 995            Azerbaijan      Snacks       Offline              C
# 996               Georgia   Baby Food       Offline              H
# 997  United Arab Emirates  Vegetables        Online              C
# 998               Finland   Household       Offline              L
# 999              Portugal      Cereal       Offline              C
#
#      Order Date   Order ID   Ship Date  Units Sold  Unit Price  Unit Cost  \
# 0    10/18/2014  686800706  10/31/2014        8446      437.20     263.33
# ...

# %%
df['Total Profit']=df['Total Profit']-1

# %%
df
# Out:
#                   Country   Item Type Sales Channel Order Priority  \
# 0                   Libya   Cosmetics       Offline              M
# 1                  Canada  Vegetables        Online              M
# 2                   Libya   Baby Food       Offline              C
# 3                   Japan      Cereal       Offline              C
# 4                    Chad      Fruits       Offline              H
# ..                    ...         ...           ...            ...
# 995            Azerbaijan      Snacks       Offline              C
# 996               Georgia   Baby Food       Offline              H
# 997  United Arab Emirates  Vegetables        Online              C
# 998               Finland   Household       Offline              L
# 999              Portugal      Cereal       Offline              C
#
#      Order Date   Order ID   Ship Date  Units Sold  Unit Price  Unit Cost  \
# 0    10/18/2014  686800706  10/31/2014        8446      437.20     263.33
# ...

# %%
df.drop(0)
# Out:
#                   Country   Item Type Sales Channel Order Priority  \
# 1                  Canada  Vegetables        Online              M
# 2                   Libya   Baby Food       Offline              C
# 3                   Japan      Cereal       Offline              C
# 4                    Chad      Fruits       Offline              H
# 5                 Armenia      Cereal        Online              H
# ..                    ...         ...           ...            ...
# 995            Azerbaijan      Snacks       Offline              C
# 996               Georgia   Baby Food       Offline              H
# 997  United Arab Emirates  Vegetables        Online              C
# 998               Finland   Household       Offline              L
# 999              Portugal      Cereal       Offline              C
#
#      Order Date   Order ID   Ship Date  Units Sold  Unit Price  Unit Cost  \
# 1     11/7/2011  185941302   12/8/2011        3018      154.06      90.93
# ...

# %%
#statical summery
df.describe
# Out:
# <bound method NDFrame.describe of                   Country   Item Type Sales Channel Order Priority  \
# 0                   Libya   Cosmetics       Offline              M
# 1                  Canada  Vegetables        Online              M
# 2                   Libya   Baby Food       Offline              C
# 3                   Japan      Cereal       Offline              C
# 4                    Chad      Fruits       Offline              H
# ..                    ...         ...           ...            ...
# 995            Azerbaijan      Snacks       Offline              C
# 996               Georgia   Baby Food       Offline              H
# 997  United Arab Emirates  Vegetables        Online              C
# 998               Finland   Household       Offline              L
# 999              Portugal      Cereal       Offline              C
#
#      Order Date   Order ID   Ship Date  Units Sold  Unit Price  Unit Cost  \
# ...

# %%
df.describe()
# Out:
#            Order ID   Units Sold  Unit Price    Unit Cost  Total Revenue  \
# count  1.000000e+03  1000.000000  1000.00000  1000.000000   1.000000e+03
# mean   5.496813e+08  5053.988000   262.10684   184.965110   1.327322e+06
# std    2.571334e+08  2901.375317   216.02106   175.289311   1.486515e+06
# min    1.029280e+08    13.000000     9.33000     6.920000   2.043250e+03
# 25%    3.280740e+08  2420.250000    81.73000    56.670000   2.811919e+05
# 50%    5.566097e+08  5184.000000   154.06000    97.440000   7.549392e+05
# 75%    7.696945e+08  7536.750000   421.89000   263.330000   1.733503e+06
# max    9.955298e+08  9998.000000   668.27000   524.960000   6.617210e+06
#
#          Total Cost  Total Profit
# count  1.000000e+03  1.000000e+03
# mean   9.361192e+05  3.912016e+05
# std    1.162571e+06  3.836402e+05
# min    1.416750e+03  5.316100e+02
# 25%    1.649319e+05  9.837512e+04
# 50%    4.647261e+05  2.772250e+05
# 75%    1.141750e+06  5.484558e+05
# ...
