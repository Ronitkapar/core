# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
corpus = 'I am happy to join with you today in what will go down in history as the greatest demonstration for freedom in the history of our nation. Five score years ago a great American in whose symbolic shadow we stand today signed the Emancipation Proclamation. This momentous decree is a great beacon light of hope to millions of Negro slaves who had been seared in the flames of withering injustice. It came as a joyous daybreak to end the long night of their captivity. But 100 years later the Negro still is not free. One hundred years later the life of the Negro is still badly crippled by the manacles of segregation and the chains of discrimination. One hundred years later the Negro lives on a lonely island of poverty in the midst of a vast ocean of material prosperity. One hundred years later the Negro is still languished in the corners of American society and finds himself in exile in his own land. So we’ve come here today to dramatize a shameful condition.'
words=list(corpus)

# %%
for word in words:
    print(word +' -----> '+ stemming.stem(word))
# Out:
# I -----> i
#   ----->
# a -----> a
# m -----> m
#   ----->
# h -----> h
# a -----> a
# p -----> p
# p -----> p
# y -----> y
#   ----->
# t -----> t
# o -----> o
#   ----->
# j -----> j
# o -----> o
# i -----> i
# n -----> n
#   ----->
# w -----> w
# i -----> i
# t -----> t
# h -----> h
#   ----->
# y -----> y
# o -----> o
# u -----> u
#   ----->
# t -----> t
# o -----> o
# d -----> d
# a -----> a
# y -----> y
#   ----->
# i -----> i
# n -----> n
#   ----->
# w -----> w
# h -----> h
# a -----> a
# t -----> t
#   ----->
# w -----> w
# i -----> i
# l -----> l
# l -----> l
#   ----->
# g -----> g
# o -----> o
#   ----->
# d -----> d
# o -----> o
# w -----> w
# n -----> n
#   ----->
# i -----> i
# n -----> n
#   ----->
# h -----> h
# i -----> i
# s -----> s
# t -----> t
# o -----> o
# r -----> r
# y -----> y
#   ----->
# a -----> a
# s -----> s
#   ----->
# t -----> t
# h -----> h
# e -----> e
#   ----->
# g -----> g
# r -----> r
# e -----> e
# a -----> a
# t -----> t
# e -----> e
# ...

# %%
# Regestemmer class

from nltk import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer(r'ing$|e$|able$', min=4)

# %%
print(reg_stemmer.stem("believable")) # Output: believ
# Out:
# believ

# %%
from nltk.stem import SnowballStemmer

# Corrected the spelling: SnowballStemmer (two 'm's)
snowball = SnowballStemmer('english')

words = ["running", "runs", "easily", "fairly"] # Defining words if not already set

for word in words:
    print(word + ' ---> ' + snowball.stem(word))
# Out:
# running ---> run
# runs ---> run
# easily ---> easili
# fairly ---> fair

# %%
# Lemmatizer 

from nltk.stem import WordNetLemmatizer
lemitize=WordNetLemmatizer()

lemitize.lemmatize("words", pos='v')

##wrong -> correct way below!
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~/anaconda3/envs/py3.12/lib/python3.12/site-packages/nltk/corpus/util.py:85, in LazyCorpusLoader.__load(self)
#      84 try:
# ---> 85     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      86 except LookupError:
#
# File ~/anaconda3/envs/py3.12/lib/python3.12/site-packages/nltk/data.py:738, in find(resource_name, paths)
#     737 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 738 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'wordnet' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'corpora/wordnet.zip/wordnet/'
#
#   Searched in:
# ...

# %%
import nltk
from nltk.stem import WordNetLemmatizer

# Required download for the lemmatizer to work
nltk.download('wordnet')

# 1. Initialize with correct spelling
lemmatizer = WordNetLemmatizer()

# 2. Use the correct POS tag
# "words" is a noun, so use pos='n' (default)
print(lemmatizer.lemmatize("words", pos='n')) # Output: word
# Out:
# [nltk_data] Downloading package wordnet to /home/ronit/nltk_data...
# word

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

words_list = ["rocks", "corpora", "better", "running"]

# Using a list comprehension
# pos='n' is default, but we'll stick to it for clarity
lemmatized_words = [lemmatizer.lemmatize(w, pos='n') for w in words_list]

print(lemmatized_words)
# Output: ['rock', 'corpus', 'better', 'running']
# Out:
# ['rock', 'corpus', 'better', 'running']
