# %% [markdown]
# # tokenization

# %%
## paragraph --> sentences

import nltk
from nltk.tokenize import sent_tokenize  #sent_tokenize is used to split a block of text into individual sentences

paragraph = 'Five score years ago a great American in whose symbolic shadow we stand today signed the Emancipation Proclamation. This momentous decree is a great beacon light of hope to millions of Negro slaves who had been seared in the flames of withering injustice. It came as a joyous daybreak to end the long night of their captivity. But 100 years later the Negro still is not free. One hundred years later the life of the Negro is still badly crippled by the manacles of segregation and the chains of discrimination. One hundred years later the Negro lives on a lonely island of poverty in the midst of a vast ocean of material prosperity. One hundred years later the Negro is still languished in the corners of American society and finds himself in exile in his own land. So we’ve come here today to dramatize a shameful condition.'

sentences = sent_tokenize(paragraph) #paragraph to sentences

#printing line by line
for sentence in sentences:
    print(sentence)
# Out:
# Five score years ago a great American in whose symbolic shadow we stand today signed the Emancipation Proclamation.
# This momentous decree is a great beacon light of hope to millions of Negro slaves who had been seared in the flames of withering injustice.
# It came as a joyous daybreak to end the long night of their captivity.
# But 100 years later the Negro still is not free.
# One hundred years later the life of the Negro is still badly crippled by the manacles of segregation and the chains of discrimination.
# One hundred years later the Negro lives on a lonely island of poverty in the midst of a vast ocean of material prosperity.
# One hundred years later the Negro is still languished in the corners of American society and finds himself in exile in his own land.
# So we’ve come here today to dramatize a shameful condition.

# %%
## paragraph --> words

from nltk import word_tokenize

words = word_tokenize(paragraph)
print(words)
print(f"The length of word in paragraph is {len(words)}")
# Out:
# ['Five', 'score', 'years', 'ago', 'a', 'great', 'American', 'in', 'whose', 'symbolic', 'shadow', 'we', 'stand', 'today', 'signed', 'the', 'Emancipation', 'Proclamation', '.', 'This', 'momentous', 'decree', 'is', 'a', 'great', 'beacon', 'light', 'of', 'hope', 'to', 'millions', 'of', 'Negro', 'slaves', 'who', 'had', 'been', 'seared', 'in', 'the', 'flames', 'of', 'withering', 'injustice', '.', 'It', 'came', 'as', 'a', 'joyous', 'daybreak', 'to', 'end', 'the', 'long', 'night', 'of', 'their', 'captivity', '.', 'But', '100', 'years', 'later', 'the', 'Negro', 'still', 'is', 'not', 'free', '.', 'One', 'hundred', 'years', 'later', 'the', 'life', 'of', 'the', 'Negro', 'is', 'still', 'badly', 'crippled', 'by', 'the', 'manacles', 'of', 'segregation', 'and', 'the', 'chains', 'of', 'discrimination', '.', 'One', 'hundred', 'years', 'later', 'the', 'Negro', 'lives', 'on', 'a', 'lonely', 'island', 'of', 'poverty', 'in', 'the', 'midst', 'of', 'a', 'vast', 'ocean', 'of', 'material', 'prosperity', '.', 
# ...
